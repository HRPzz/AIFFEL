# %% [markdown]
#  Background removing
#
#
#
# ### **Let's start!**

# %% [markdown]
# ## 1. Preparation

# %% [markdown]
# <p align="justify">In the top menu of this session, select <b>Runtime -> Change runtime type</b>, and set <b>Hardware Accelerator</b> to <b>GPU</b>.</p>
#
# <p align="justify">Clone the repository, and download the pre-trained model:</p>

# %%
import os

# clone the repository
# %cd /content
if not os.path.exists('MODNet'):
  # !git clone https://github.com/ZHKKKe/MODNet
# %cd MODNet/

# dowload the pre-trained ckpt for image matting
pretrained_ckpt = 'pretrained/modnet_photographic_portrait_matting.ckpt'
if not os.path.exists(pretrained_ckpt):
  # !gdown --id 1mcr7ALciuAsHCpLnrtG_eop5-EYhbCmz \
          -O pretrained/modnet_photographic_portrait_matting.ckpt
# Out:
# /content
# Cloning into 'MODNet'...
# remote: Enumerating objects: 264, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 264 (delta 27), reused 29 (delta 11), pack-reused 206
# Receiving objects: 100% (264/264), 60.77 MiB | 26.28 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# /content/MODNet
# Downloading...
# From: https://drive.google.com/uc?id=1mcr7ALciuAsHCpLnrtG_eop5-EYhbCmz
# To: /content/MODNet/pretrained/modnet_photographic_portrait_matting.ckpt
# 100% 26.3M/26.3M [00:00<00:00, 60.0MB/s]

# %% [markdown]
# ## 2. Upload Images

# %% [markdown]
# <p align="justify">Upload portrait images to be processed (only PNG and JPG format are supported):</p>

# %%
import shutil
import os
from google.colab import files

# clean and rebuild the image folders
input_folder = 'demo/image_matting/colab/input'
if os.path.exists(input_folder):
  shutil.rmtree(input_folder)
os.makedirs(input_folder)

output_folder = 'demo/image_matting/colab/output'
if os.path.exists(output_folder):
  shutil.rmtree(output_folder)
os.makedirs(output_folder)

# upload images (PNG or JPG)
image_names = list(files.upload().keys())
for image_name in image_names:
  shutil.move(image_name, os.path.join(input_folder, image_name))
# Out:
#      <input type="file" id="files-82264703-97ae-4bb1-8226-65feebfbc281" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82264703-97ae-4bb1-8226-65feebfbc281">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving couple.jpg to couple.jpg

# %% [markdown]
# ## 3. Inference

# %% [markdown]
# <p align="justify">Run the following command for alpha matte prediction:</p>

# %%
# !python -m demo.image_matting.colab.inference \
        --input-path demo/image_matting/colab/input \
        --output-path demo/image_matting/colab/output \
        --ckpt-path ./pretrained/modnet_photographic_portrait_matting.ckpt
# Out:
# Process image: couple.jpg
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3680: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# ## 4. Visualization

# %% [markdown]
# <p align="justify">Display the results (from left to right: image, foreground, and alpha matte):</p>

# %%
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import cv2

def combined_display(image, matte):
  # calculate display resolution
  w, h = image.width, image.height
  rw, rh = 800, int(h * 800 / (3 * w))
  
  # obtain predicted foreground
  image = np.asarray(image)
  if len(image.shape) == 2:
    image = image[:, :, None]
  if image.shape[2] == 1:
    image = np.repeat(image, 3, axis=2)
  elif image.shape[2] == 4:
    image = image[:, :, 0:3]
  matte = np.repeat(np.asarray(matte)[:, :, None], 3, axis=2) / 255
  foreground = image * matte + np.full(image.shape, 255) * (1 - matte)
  
  # combine image, foreground, and alpha into one line
  combined = np.concatenate((image, foreground, matte * 255), axis=1)
  combined = Image.fromarray(np.uint8(combined)).resize((rw, rh))
  return combined

# visualize all images
image_names = os.listdir(input_folder)
for image_name in image_names:
  matte_name = image_name.split('.')[0] + '.png'
  image = Image.open(os.path.join(input_folder, image_name))
  matte = Image.open(os.path.join(output_folder, matte_name))
  display(combined_display(image, matte))
  print(image_name, '\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x177 at 0x7F11DC097590>
# couple.jpg

# %%
input_folder
# Out:
# 'demo/image_matting/colab/input'

# %% [markdown]
# ## Download Results

# %% [markdown]
# <p align="justify">Download the Zip package of predicted alpha mattes:</p>

# %%
zip_filename = 'matte.zip'
if os.path.exists(zip_filename):
  os.remove(zip_filename)

os.system(f"zip -r -j {zip_filename} {output_folder}/*")
files.download(zip_filename)

# %%
# zip 으로 압축
# !zip -r /content/MODNet.zip /content/MODNet
# Out:
#   adding: content/MODNet/ (stored 0%)
#   adding: content/MODNet/LICENSE (deflated 65%)
#   adding: content/MODNet/pretrained/ (stored 0%)
#   adding: content/MODNet/pretrained/modnet_photographic_portrait_matting.ckpt (deflated 8%)
#   adding: content/MODNet/pretrained/README.md (deflated 20%)
#   adding: content/MODNet/src/ (stored 0%)
#   adding: content/MODNet/src/__pycache__/ (stored 0%)
#   adding: content/MODNet/src/__pycache__/__init__.cpython-37.pyc (deflated 25%)
#   adding: content/MODNet/src/trainer.py (deflated 75%)
#   adding: content/MODNet/src/models/ (stored 0%)
#   adding: content/MODNet/src/models/__pycache__/ (stored 0%)
#   adding: content/MODNet/src/models/__pycache__/__init__.cpython-37.pyc (deflated 25%)
#   adding: content/MODNet/src/models/__pycache__/modnet.cpython-37.pyc (deflated 55%)
#   adding: content/MODNet/src/models/backbones/ (stored 0%)
#   adding: content/MODNet/src/models/backbones/__pycache__/ (stored 0%)
#   adding: content/MODNet/src/models/backbones/__pycache__/__init__.cpython-37.pyc (deflated 14%)
#   adding: content/MODNet/src/models/backbones/__pycache__/mobilenetv2.cpython-37.pyc (deflated 47%)
#   adding: content/MODNet/src/models/backbones/__pycache__/wrapper.cpython-37.pyc (deflated 53%)
#   adding: content/MODNet/src/models/backbones/wrapper.py (deflated 72%)
#   adding: content/MODNet/src/models/backbones/__init__.py (deflated 58%)
#   adding: content/MODNet/src/models/backbones/mobilenetv2.py (deflated 71%)
#   adding: content/MODNet/src/models/modnet.py (deflated 79%)
#   adding: content/MODNet/src/models/__init__.py (stored 0%)
#   adding: content/MODNet/src/__init__.py (stored 0%)
#   adding: content/MODNet/torchscript/ (stored 0%)
#   adding: content/MODNet/torchscript/README.md (deflated 50%)
#   adding: content/MODNet/torchscript/__init__.py (stored 0%)
#   adding: content/MODNet/torchscript/export_torchscript.py (deflated 60%)
#   adding: content/MODNet/torchscript/modnet_torchscript.py (deflated 78%)
#   adding: content/MODNet/demo/ (stored 0%)
#   adding: content/MODNet/demo/video_matting/ (stored 0%)
#   adding: content/MODNet/demo/video_matting/custom/ (stored 0%)
#   adding: content/MODNet/demo/video_matting/custom/run.py (deflated 62%)
#   adding: content/MODNet/demo/video_matting/custom/requirements.txt (deflated 9%)
#   adding: content/MODNet/demo/video_matting/custom/README.md (deflated 46%)
#   adding: content/MODNet/demo/video_matting/webcam/ (stored 0%)
#   adding: content/MODNet/demo/video_matting/webcam/run.py (deflated 56%)
#   adding: content/MODNet/demo/video_matting/webcam/requirements.txt (deflated 6%)
#   adding: content/MODNet/demo/video_matting/webcam/README.md (deflated 46%)
#   adding: content/MODNet/demo/image_matting/ (stored 0%)
#   adding: content/MODNet/demo/image_matting/colab/ (stored 0%)
#   adding: content/MODNet/demo/image_matting/colab/__pycache__/ (stored 0%)
#   adding: content/MODNet/demo/image_matting/colab/__pycache__/inference.cpython-37.pyc (deflated 38%)
#   adding: content/MODNet/demo/image_matting/colab/inference.py (deflated 65%)
#   adding: content/MODNet/demo/image_matting/colab/README.md (deflated 18%)
#   adding: content/MODNet/demo/image_matting/colab/output/ (stored 0%)
#   adding: content/MODNet/demo/image_matting/colab/output/couple.png (deflated 5%)
#   adding: content/MODNet/demo/image_matting/colab/input/ (stored 0%)
#   adding: content/MODNet/demo/image_matting/colab/input/couple.jpg (deflated 0%)
#   adding: content/MODNet/README.md (deflated 57%)
#   adding: content/MODNet/doc/ (stored 0%)
#   adding: content/MODNet/doc/gif/ (stored 0%)
#   adding: content/MODNet/doc/gif/image_matting_demo.gif (deflated 5%)
#   adding: content/MODNet/doc/gif/homepage_demo.gif (deflated 6%)
#   adding: content/MODNet/doc/gif/video_matting_demo.gif (deflated 10%)
#   adding: content/MODNet/doc/gif/commercial_image_matting_website.gif (deflated 17%)
#   adding: content/MODNet/doc/gif/commercial_image_matting_model_result.gif (deflated 1%)
#   adding: content/MODNet/.git/ (stored 0%)
#   adding: content/MODNet/.git/objects/ (stored 0%)
#   adding: content/MODNet/.git/objects/info/ (stored 0%)
#   adding: content/MODNet/.git/objects/pack/ (stored 0%)
#   adding: content/MODNet/.git/objects/pack/pack-14fb365848c1895b0daa6d14e84fde2a503e4130.idx (deflated 9%)
#   adding: content/MODNet/.git/objects/pack/pack-14fb365848c1895b0daa6d14e84fde2a503e4130.pack (deflated 0%)
#   adding: content/MODNet/.git/description (deflated 14%)
#   adding: content/MODNet/.git/HEAD (stored 0%)
#   adding: content/MODNet/.git/info/ (stored 0%)
#   adding: content/MODNet/.git/info/exclude (deflated 28%)
#   adding: content/MODNet/.git/index (deflated 49%)
#   adding: content/MODNet/.git/logs/ (stored 0%)
#   adding: content/MODNet/.git/logs/HEAD (deflated 25%)
#   adding: content/MODNet/.git/logs/refs/ (stored 0%)
#   adding: content/MODNet/.git/logs/refs/heads/ (stored 0%)
#   adding: content/MODNet/.git/logs/refs/heads/master (deflated 25%)
#   adding: content/MODNet/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/MODNet/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/MODNet/.git/logs/refs/remotes/origin/HEAD (deflated 25%)
#   adding: content/MODNet/.git/branches/ (stored 0%)
#   adding: content/MODNet/.git/refs/ (stored 0%)
#   adding: content/MODNet/.git/refs/heads/ (stored 0%)
#   adding: content/MODNet/.git/refs/heads/master (stored 0%)
#   adding: content/MODNet/.git/refs/remotes/ (stored 0%)
#   adding: content/MODNet/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/MODNet/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/MODNet/.git/refs/tags/ (stored 0%)
#   adding: content/MODNet/.git/hooks/ (stored 0%)
#   adding: content/MODNet/.git/hooks/pre-push.sample (deflated 50%)
#   adding: content/MODNet/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/MODNet/.git/hooks/update.sample (deflated 68%)
#   adding: content/MODNet/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/MODNet/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/MODNet/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/MODNet/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/MODNet/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: content/MODNet/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/MODNet/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/MODNet/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: content/MODNet/.git/config (deflated 31%)
#   adding: content/MODNet/.git/packed-refs (deflated 41%)
#   adding: content/MODNet/onnx/ (stored 0%)
#   adding: content/MODNet/onnx/requirements.txt (deflated 6%)
#   adding: content/MODNet/onnx/README.md (deflated 53%)
#   adding: content/MODNet/onnx/export_onnx.py (deflated 59%)
#   adding: content/MODNet/onnx/__init__.py (stored 0%)
#   adding: content/MODNet/onnx/modnet_onnx.py (deflated 78%)
#   adding: content/MODNet/onnx/inference_onnx.py (deflated 64%)
#   adding: content/MODNet/.gitignore (deflated 44%)
#   adding: content/MODNet/matte.zip (stored 0%)

# %%
# zip 파일 로컬에 저장
from google.colab import files
files.download("/content/MODNet.zip")
